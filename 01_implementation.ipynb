# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image

# For training improvements
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint  # Control training
from tensorflow.keras.layers import BatchNormalization                # Normalize activations

# %%
# Path to dataset directory (should contain subfolders like 'with_mask', 'without_mask')
train_dir = 'data/'

# %%
# ImageDataGenerator helps in Utility to load, preprocess, Normalizing images, Augmenting data (rotation, zoom, flip)
train_gen = ImageDataGenerator(
    rescale = 1./255,           # Normalize pixel values (0–255 → 0–1)
    validation_split = 0.2,     # Split dataset into 80% train / 20% validation
    rotation_range = 20,        # Randomly rotates images up to ±20° to improve generalization.
    zoom_range = 0.2,           # Random zoom to make model robust to scale changes
    horizontal_flip = True      # Flip images horizontally to increase dataset diversity.
)


# Go to my dataset folder, load images in batches, apply preprocessing & augmentation, and assign labels automatically
train_data = train_gen.flow_from_directory(
    train_dir,
    # Model cannot handle different sizes so we can Resize all images to 128x128 fixed size which can give more detail and speed
    target_size = (128, 128),   # Resize images to 128x128 pixels
    batch_size = 32,            # Loads 32 images at a time
    class_mode = 'binary',      # Binary classification (mask / no mask)
    subset = 'training'         # Use training split
)


# Load validation data
val_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(128, 128),   # Same size as training data
    batch_size=32,
    class_mode='binary',
    subset='validation'       # Use validation split
)
# Out:
# Found 6043 images belonging to 2 classes.
# Found 1510 images belonging to 2 classes.

# %%
# Display class label mapping (e.g., {'with_mask': 0, 'without_mask': 1})
print("Class Labels:", train_data.class_indices)
# Out:
# Class Labels: {'with_mask': 0, 'without_mask': 1}

# %%
# 1. Feature Extraction → (Conv + BN + Pool)
# 2. Feature Conversion → (Flatten)
# 3. Decision Making → (Dense + Dropout + Output)

model = Sequential([

    # First Convolution Block
    # (3,3) → Filter Size (Kernel Size) ,Each filter is 3×3, It looks at a small patch of the image at a time, captures local features like edges, corners, textures.
    # input_shape = (128,128,3) -> 128x128 pixels, 3 channels (RGB)
    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),  # Extract low-level features
    BatchNormalization(),   # Normalize outputs → stabilizes training

    # Reduce spatial size (downsampling)
    # reduce size + keep important features
    MaxPooling2D(2,2),      

    # Second Convolution Block
    Conv2D(64, (3,3), activation='relu'),  # Learn more complex features
    BatchNormalization(),   # Normalize again
    MaxPooling2D(2,2),      # Downsample

    # Third Convolution Block
    Conv2D(128, (3,3), activation='relu'), # High-level feature extraction
    BatchNormalization(),   # Normalize
    MaxPooling2D(2,2),      # Downsample

    # CNN = Detect edges, shapes
    # Flatten = Convert findings into list
    # Dense = Decide final answer
    # Flatten feature maps into 1D vector
    Flatten(),

    # Fully connected layer
    Dense(128, activation='relu'),  # Learn patterns from extracted features
    # Not using dropout after every layer because in CNN it can disturb to feature learning means it can remove information i.e spatial features
    # Here we used Batch normalization to stabilize training, can prevent from overfitting, adds slight regularization.
    # after dense used dropout because dense layer do decision making so not sensitive to spacial structure
    # Prevent overfitting by randomly dropping neurons
    Dropout(0.5),                   

    # Output layer (binary classification)
    Dense(1, activation='sigmoid')  # Output probability (0 to 1) it will give 0    or 1 (mask or no mask)
])

# %%
# Compile model (configure training)
model.compile(
    optimizer = Adam( learning_rate=0.001 ),  # Optimizer with learning rate
    loss='binary_crossentropy',               # Loss for binary classification
    metrics=['accuracy']                      # Track accuracy
)

# %%
# EarlyStopping stops training if validation loss doesn't improve
early_stop = EarlyStopping(
    monitor = 'val_loss',           # Watch validation loss
    patience = 3,                   # Wait 3 epochs before stopping
    restore_best_weights = True     # Restore best model weights
)

# ModelCheckpoint saves the best model during training
checkpoint = ModelCheckpoint(
    "best_model.keras",             # File name
    monitor = 'val_accuracy',       # Watch validation accuracy
    save_best_only = True           # Save only best version
)

# %%
# Train the model
history = model.fit(
    train_data,                          # Training data generator
    epochs = 10,                           # Number of training cycles
    validation_data = val_data,            # Validation data

    steps_per_epoch = len(train_data),     # Number of batches per epoch
    validation_steps = len(val_data),      # Validation batches

    callbacks = [early_stop, checkpoint]   # Callbacks are tools that monitor training and take action automatically.
)
# Out:
# Epoch 1/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 89s 458ms/step - accuracy: 0.8319 - loss: 0.8584 - val_accuracy: 0.6093 - val_loss: 1.8095
# Epoch 2/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 89s 471ms/step - accuracy: 0.8843 - loss: 0.3130 - val_accuracy: 0.8742 - val_loss: 0.3031
# Epoch 3/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 89s 468ms/step - accuracy: 0.8961 - loss: 0.2969 - val_accuracy: 0.8801 - val_loss: 0.4638
# Epoch 4/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 83s 438ms/step - accuracy: 0.9080 - loss: 0.2449 - val_accuracy: 0.9073 - val_loss: 0.3097
# Epoch 5/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 82s 434ms/step - accuracy: 0.9161 - loss: 0.2173 - val_accuracy: 0.9397 - val_loss: 0.1696
# Epoch 6/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 91s 479ms/step - accuracy: 0.9224 - loss: 0.2002 - val_accuracy: 0.9404 - val_loss: 0.1685
# Epoch 7/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 86s 452ms/step - accuracy: 0.9371 - loss: 0.1735 - val_accuracy: 0.8795 - val_loss: 0.2949
# Epoch 8/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 86s 455ms/step - accuracy: 0.9389 - loss: 0.1660 - val_accuracy: 0.9086 - val_loss: 0.2634
# Epoch 9/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 94s 495ms/step - accuracy: 0.9447 - loss: 0.1488 - val_accuracy: 0.9364 - val_loss: 0.1801

# %%
# Plot training results (accuracy & loss)

plt.figure(figsize=(10,4))

# Plot accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')       # Training accuracy
plt.plot(history.history['val_accuracy'], label='Val Accuracy')     # Validation accuracy
plt.title("Accuracy")
plt.legend()

# Plot loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')               # Training loss
plt.plot(history.history['val_loss'], label='Val Loss')             # Validation loss
plt.title("Loss")
plt.legend()

plt.show()

# %%
img_path = 'image2.jpg'  # Path to test image

# Load and resize image
img = image.load_img(img_path, target_size=(128, 128))

# Convert image to array and normalize
img_array = image.img_to_array(img) / 255.0

# Add batch dimension (model expects shape: (1, 128, 128, 3))
# (1, 128, 128, 3)
#  ↑   ↑    ↑    ↑
#  |   |    |    |
#  |   |    |    └── Channels (RGB)
#  |   |    └────── Width
#  |   └────────── Height
#  └────────────── Batch size
img_array = np.expand_dims(img_array, axis=0)

# Predict probability
prediction = model.predict(img_array)

print("Raw Prediction:", prediction)

# Convert probability to class label
if prediction[0][0] > 0.5:
    print("Prediction: WITHOUT Mask ❌😷")
else:
    print("Prediction: WITH Mask ✅😷")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Raw Prediction: [[0.00636704]]
# Prediction: WITH Mask ✅😷

# %%
# Save trained model to file
model.save("mask_final.keras")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [raw]
# Data Handling & Preprocessing
#
#     ImageDataGenerator -> Utility to load, preprocess, and augment images in real-time during training.
#     rescale=1./255 -> Normalizes pixel values from `[0–255]` to `[0–1]` for stable learning.
#     validation_split=0.2 -> Splits dataset into 80% training and 20% validation automatically.
#
#     rotation_range=20 -> Randomly rotates images up to ±20° to improve generalization.
#     Rotation is used to expose the model to different orientations so it can recognize faces regardless of how they are tilted
#
#     zoom_range=0.2 -> Randomly zooms images to make model robust to scale changes.
#     horizontal_flip=True -> Flips images horizontally to increase dataset diversity.
#
# Data Loading
#
#     flow_from_directory() -> Loads images from folder structure and assigns labels automatically.
#     target_size=(128,128) -> Resizes all images to a fixed size required by the model.
#     batch_size=32 -> Number of images processed in one iteration (mini-batch learning).
#     class_mode='binary' -> Specifies binary classification (two classes).
#     subset='training/validation' -> Selects portion of data based on validation split.
#
# CNN Layers (Feature Extraction)
#
#     Conv2D(filters, kernel_size) -> Extracts spatial features using learnable filters.
#     activation='relu' -> Introduces non-linearity and avoids vanishing gradient problem.
#     BatchNormalization() -> Normalizes layer outputs to stabilize and speed up training.
#     MaxPooling2D(pool_size) -> Reduces feature map size while keeping important features.
#
# Transition Layer
#
#     Flatten() -> Converts 2D feature maps into 1D vector for dense layers.
#
# Dense Layers (Learning Patterns)
#
#     Dense(units) -> Fully connected layer that learns high-level patterns.
#     Dropout(rate) -> Randomly disables neurons to prevent overfitting.
#
# Output Layer
#
#     Dense(1, activation='sigmoid') -> Outputs probability for binary classification (0–1).
#
# Model Compilation
#
#     Adam(learning_rate=0.001) -> Optimizer that updates weights using adaptive learning rates.
#     loss='binary_crossentropy' -> Measures error for binary classification tasks.
#     metrics=['accuracy'] -> Tracks how many predictions are correct.
#
# Callbacks (Training Control)
#
#     EarlyStopping -> Stops training when validation performance stops improving.
#     patience=3 -> Waits 3 epochs before stopping to avoid premature stopping.
#     restore_best_weights=True -> Restores best-performing model weights.
#     ModelCheckpoint -> Saves the best model during training.
#     save_best_only=True -> Saves only when performance improves.
#
# Model Training
#
#     model.fit() -> Trains the model on given data.
#     epochs=10 -> Number of times entire dataset is passed through the model.
#     steps_per_epoch=len(train_data) -> Number of batches per epoch.
#     validation_data -> Data used to evaluate model during training.
#
# Evaluation & Visualization
#
#     history.history -> Stores training and validation metrics over epochs.
#     plt.plot() -> Visualizes accuracy and loss trends.
#
# Prediction
#
#     load_img() -> Loads image from file.
#     img_to_array() -> Converts image into numerical array.
#     np.expand_dims() -> Adds batch dimension for model input.
#     model.predict() -> Outputs prediction probabilities.
#     > 0.5 threshold -> Converts probability into binary class.
#
# Model Saving
#     model.save() Saves trained model for future use.
